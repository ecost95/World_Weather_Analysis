# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
            
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | anshun
# Processing Record 2 of Set 1 | sidi ali
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | ukiah
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | filingue
# Processing Record 8 of Set 1 | salta
# Processing Record 9 of Set 1 | fort nelson
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | umm kaddadah
# Processing Record 13 of Set 1 | san cristobal
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | ust-kulom
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | saint-joseph
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | muisne
# Processing Record 21 of Set 1 | mildura
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | terryville
# Processing Record 28 of Set 1 | grindavik
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | esso
# Processing Record 31 of Set 1 | sibolga
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | santa cruz cabralia
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | port hardy
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | tautira
# Processing Record 44 of Set 1 | churapcha
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 1 | maghama
# City not found. Skipping...
# Processing Record 48 of Set 1 | buala
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | udachnyy
# Processing Record 1 of Set 2 | yar-sale
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | rafraf
# Processing Record 5 of Set 2 | plymouth
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | longyearbyen
# Processing Record 8 of Set 2 | hirara
# Processing Record 9 of Set 2 | kazanskoye
# Processing Record 10 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 2 | shalya
# Processing Record 12 of Set 2 | khash
# Processing Record 13 of Set 2 | sola
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | torbay
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | manzanillo
# Processing Record 19 of Set 2 | saint george
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 22 of Set 2 | sabha
# Processing Record 23 of Set 2 | limbang
# Processing Record 24 of Set 2 | huarmey
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | bama
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | jinxiang
# Processing Record 31 of Set 2 | tiznit
# Processing Record 32 of Set 2 | ambovombe
# Processing Record 33 of Set 2 | zhanaozen
# Processing Record 34 of Set 2 | inhambane
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | devonport
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | port hedland
# Processing Record 39 of Set 2 | isangel
# Processing Record 40 of Set 2 | kahului
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | geraldton
# Processing Record 44 of Set 2 | nanortalik
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | visnes
# Processing Record 47 of Set 2 | kawalu
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | hovd
# Processing Record 1 of Set 3 | honningsvag
# Processing Record 2 of Set 3 | zhigansk
# Processing Record 3 of Set 3 | pisco
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | bahir dar
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | santa cruz
# Processing Record 8 of Set 3 | makueni
# Processing Record 9 of Set 3 | hambantota
# Processing Record 10 of Set 3 | ballina
# Processing Record 11 of Set 3 | gamboma
# Processing Record 12 of Set 3 | angoche
# Processing Record 13 of Set 3 | yeniseysk
# Processing Record 14 of Set 3 | nome
# Processing Record 15 of Set 3 | sitka
# Processing Record 16 of Set 3 | mnogovershinnyy
# Processing Record 17 of Set 3 | richards bay
# Processing Record 18 of Set 3 | rockhampton
# Processing Record 19 of Set 3 | fengzhen
# Processing Record 20 of Set 3 | betsiamites
# Processing Record 21 of Set 3 | hukuntsi
# Processing Record 22 of Set 3 | port lincoln
# Processing Record 23 of Set 3 | bambous virieux
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | nagato
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | haines junction
# Processing Record 28 of Set 3 | kedrovyy
# Processing Record 29 of Set 3 | jumla
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | makamba
# Processing Record 32 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 33 of Set 3 | hasaki
# Processing Record 34 of Set 3 | mezen
# Processing Record 35 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 3 | srednekolymsk
# Processing Record 38 of Set 3 | luderitz
# Processing Record 39 of Set 3 | namatanai
# Processing Record 40 of Set 3 | piacabucu
# Processing Record 41 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | honiara
# Processing Record 44 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 3 | salinopolis
# Processing Record 46 of Set 3 | codrington
# Processing Record 47 of Set 3 | chokurdakh
# Processing Record 48 of Set 3 | athabasca
# Processing Record 49 of Set 3 | point pedro
# Processing Record 50 of Set 3 | conceicao do araguaia
# Processing Record 1 of Set 4 | marion
# Processing Record 2 of Set 4 | carutapera
# Processing Record 3 of Set 4 | san policarpo
# Processing Record 4 of Set 4 | nusaybin
# Processing Record 5 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 6 of Set 4 | caborca
# Processing Record 7 of Set 4 | bathsheba
# Processing Record 8 of Set 4 | saint-pierre
# Processing Record 9 of Set 4 | vetlanda
# Processing Record 10 of Set 4 | desaguadero
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | vila velha
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | lumeje
# Processing Record 15 of Set 4 | hermanus
# Processing Record 16 of Set 4 | takaka
# Processing Record 17 of Set 4 | tarakan
# Processing Record 18 of Set 4 | kavieng
# Processing Record 19 of Set 4 | qaanaaq
# Processing Record 20 of Set 4 | saskylakh
# Processing Record 21 of Set 4 | berlevag
# Processing Record 22 of Set 4 | eydhafushi
# Processing Record 23 of Set 4 | vila
# Processing Record 24 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 4 | xai-xai
# Processing Record 26 of Set 4 | chuy
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | benghazi
# Processing Record 29 of Set 4 | nha trang
# Processing Record 30 of Set 4 | dresden
# Processing Record 31 of Set 4 | la palma
# Processing Record 32 of Set 4 | carpentras
# Processing Record 33 of Set 4 | lagunas
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | thunder bay
# Processing Record 36 of Set 4 | banda aceh
# Processing Record 37 of Set 4 | mahasamund
# Processing Record 38 of Set 4 | khasan
# Processing Record 39 of Set 4 | wajima
# Processing Record 40 of Set 4 | talnakh
# Processing Record 41 of Set 4 | mogadishu
# Processing Record 42 of Set 4 | nago
# Processing Record 43 of Set 4 | delhi
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | waipawa
# Processing Record 46 of Set 4 | meulaboh
# Processing Record 47 of Set 4 | kencong
# Processing Record 48 of Set 4 | la rioja
# Processing Record 49 of Set 4 | pital
# Processing Record 50 of Set 4 | atambua
# Processing Record 1 of Set 5 | mufumbwe
# Processing Record 2 of Set 5 | ruteng
# Processing Record 3 of Set 5 | bitung
# Processing Record 4 of Set 5 | nelson bay
# Processing Record 5 of Set 5 | aksu
# Processing Record 6 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 5 | tanout
# Processing Record 8 of Set 5 | provideniya
# Processing Record 9 of Set 5 | saint-francois
# Processing Record 10 of Set 5 | clyde river
# Processing Record 11 of Set 5 | narsaq
# Processing Record 12 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 5 | cidreira
# Processing Record 14 of Set 5 | huilong
# Processing Record 15 of Set 5 | bani
# Processing Record 16 of Set 5 | tazovskiy
# Processing Record 17 of Set 5 | koumac
# Processing Record 18 of Set 5 | mainburg
# Processing Record 19 of Set 5 | ribeira grande
# Processing Record 20 of Set 5 | laguna
# Processing Record 21 of Set 5 | yulara
# Processing Record 22 of Set 5 | matagami
# Processing Record 23 of Set 5 | sinnamary
# Processing Record 24 of Set 5 | loiza
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | coquimbo
# Processing Record 27 of Set 5 | la reforma
# Processing Record 28 of Set 5 | noumea
# Processing Record 29 of Set 5 | tabuk
# Processing Record 30 of Set 5 | wellington
# Processing Record 31 of Set 5 | yangjiang
# Processing Record 32 of Set 5 | los llanos de aridane
# Processing Record 33 of Set 5 | valderrama
# Processing Record 34 of Set 5 | takoradi
# Processing Record 35 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 36 of Set 5 | hobyo
# Processing Record 37 of Set 5 | kruisfontein
# Processing Record 38 of Set 5 | kiruna
# Processing Record 39 of Set 5 | yerofey pavlovich
# Processing Record 40 of Set 5 | seoul
# Processing Record 41 of Set 5 | onguday
# Processing Record 42 of Set 5 | lagoa
# Processing Record 43 of Set 5 | benguela
# Processing Record 44 of Set 5 | santo antonio do amparo
# Processing Record 45 of Set 5 | westport
# Processing Record 46 of Set 5 | malakal
# Processing Record 47 of Set 5 | santa maria
# Processing Record 48 of Set 5 | buenos aires
# Processing Record 49 of Set 5 | kasungu
# Processing Record 50 of Set 5 | esperance
# Processing Record 1 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 2 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 6 | mandalgovi
# Processing Record 4 of Set 6 | rincon
# Processing Record 5 of Set 6 | laharpur
# Processing Record 6 of Set 6 | san quintin
# Processing Record 7 of Set 6 | kabompo
# Processing Record 8 of Set 6 | constitucion
# Processing Record 9 of Set 6 | concarneau
# Processing Record 10 of Set 6 | buin
# Processing Record 11 of Set 6 | tome-acu
# City not found. Skipping...
# Processing Record 12 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | emerald
# Processing Record 14 of Set 6 | gondar
# Processing Record 15 of Set 6 | ilulissat
# Processing Record 16 of Set 6 | saldanha
# Processing Record 17 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 6 | marquette
# Processing Record 20 of Set 6 | dasoguz
# Processing Record 21 of Set 6 | asau
# Processing Record 22 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 6 | thinadhoo
# Processing Record 24 of Set 6 | ahipara
# Processing Record 25 of Set 6 | coihaique
# Processing Record 26 of Set 6 | lavrentiya
# Processing Record 27 of Set 6 | beringovskiy
# Processing Record 28 of Set 6 | tessalit
# Processing Record 29 of Set 6 | lardos
# Processing Record 30 of Set 6 | bemidji
# Processing Record 31 of Set 6 | shingu
# Processing Record 32 of Set 6 | oranjemund
# Processing Record 33 of Set 6 | oshakati
# Processing Record 34 of Set 6 | chara
# Processing Record 35 of Set 6 | assiniboia
# Processing Record 36 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 6 | mana
# Processing Record 38 of Set 6 | lazaro cardenas
# Processing Record 39 of Set 6 | mendahara
# City not found. Skipping...
# Processing Record 40 of Set 6 | conroe
# Processing Record 41 of Set 6 | yacuiba
# Processing Record 42 of Set 6 | metro
# Processing Record 43 of Set 6 | shenjiamen
# Processing Record 44 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 6 | tianpeng
# Processing Record 46 of Set 6 | dubbo
# Processing Record 47 of Set 6 | charters towers
# Processing Record 48 of Set 6 | sterling
# Processing Record 49 of Set 6 | mitu
# Processing Record 50 of Set 6 | jalu
# Processing Record 1 of Set 7 | xushan
# Processing Record 2 of Set 7 | nouadhibou
# Processing Record 3 of Set 7 | mangotsfield
# Processing Record 4 of Set 7 | kurkino
# Processing Record 5 of Set 7 | kurilsk
# Processing Record 6 of Set 7 | kiama
# Processing Record 7 of Set 7 | neiafu
# Processing Record 8 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 7 | kolokani
# Processing Record 10 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 7 | salalah
# Processing Record 12 of Set 7 | atar
# Processing Record 13 of Set 7 | maceio
# Processing Record 14 of Set 7 | quatre cocos
# Processing Record 15 of Set 7 | cherskiy
# Processing Record 16 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 7 | fort morgan
# Processing Record 18 of Set 7 | alcudia
# Processing Record 19 of Set 7 | tarangnan
# Processing Record 20 of Set 7 | khani
# Processing Record 21 of Set 7 | dikson
# Processing Record 22 of Set 7 | marienburg
# Processing Record 23 of Set 7 | kavaratti
# Processing Record 24 of Set 7 | kaitangata
# Processing Record 25 of Set 7 | abu dhabi
# Processing Record 26 of Set 7 | riyadh
# Processing Record 27 of Set 7 | byron bay
# Processing Record 28 of Set 7 | kaeo
# Processing Record 29 of Set 7 | maidstone
# Processing Record 30 of Set 7 | tabou
# Processing Record 31 of Set 7 | jurilovca
# Processing Record 32 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 7 | road town
# Processing Record 34 of Set 7 | okato
# Processing Record 35 of Set 7 | oudtshoorn
# Processing Record 36 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 7 | nhulunbuy
# Processing Record 38 of Set 7 | moundou
# Processing Record 39 of Set 7 | akdepe
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | olafsvik
# Processing Record 42 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 7 | otjiwarongo
# Processing Record 44 of Set 7 | xuanhua
# Processing Record 45 of Set 7 | valparaiso
# Processing Record 46 of Set 7 | antalaha
# Processing Record 47 of Set 7 | sao filipe
# Processing Record 48 of Set 7 | shache
# Processing Record 49 of Set 7 | rey bouba
# Processing Record 50 of Set 7 | palmer
# Processing Record 1 of Set 8 | nemuro
# Processing Record 2 of Set 8 | praya
# Processing Record 3 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 8 | oleksandrivka
# Processing Record 5 of Set 8 | maniitsoq
# Processing Record 6 of Set 8 | biskamzha
# Processing Record 7 of Set 8 | gornopravdinsk
# Processing Record 8 of Set 8 | dunedin
# Processing Record 9 of Set 8 | norwalk
# Processing Record 10 of Set 8 | samana
# Processing Record 11 of Set 8 | lasa
# Processing Record 12 of Set 8 | berberati
# Processing Record 13 of Set 8 | raymondville
# Processing Record 14 of Set 8 | gigmoto
# Processing Record 15 of Set 8 | rawson
# Processing Record 16 of Set 8 | bonfim
# Processing Record 17 of Set 8 | mount isa
# Processing Record 18 of Set 8 | oriximina
# Processing Record 19 of Set 8 | kharp
# Processing Record 20 of Set 8 | komsomolskiy
# Processing Record 21 of Set 8 | chimbote
# Processing Record 22 of Set 8 | yarmouth
# Processing Record 23 of Set 8 | tura
# Processing Record 24 of Set 8 | kloulklubed
# Processing Record 25 of Set 8 | saint-augustin
# Processing Record 26 of Set 8 | vershino-darasunskiy
# Processing Record 27 of Set 8 | bowen
# Processing Record 28 of Set 8 | champerico
# Processing Record 29 of Set 8 | kidal
# Processing Record 30 of Set 8 | batagay
# Processing Record 31 of Set 8 | le havre
# Processing Record 32 of Set 8 | puerto escondido
# Processing Record 33 of Set 8 | lorengau
# Processing Record 34 of Set 8 | tevaitoa
# Processing Record 35 of Set 8 | lompoc
# Processing Record 36 of Set 8 | sakaraha
# Processing Record 37 of Set 8 | dustlik
# Processing Record 38 of Set 8 | shuyskoye
# Processing Record 39 of Set 8 | magdug
# Processing Record 40 of Set 8 | andros town
# Processing Record 41 of Set 8 | jerome
# Processing Record 42 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 43 of Set 8 | arkhangelskoye
# Processing Record 44 of Set 8 | samarai
# Processing Record 45 of Set 8 | ponazyrevo
# Processing Record 46 of Set 8 | nizwa
# Processing Record 47 of Set 8 | ha giang
# Processing Record 48 of Set 8 | verkhnevilyuysk
# Processing Record 49 of Set 8 | bukama
# Processing Record 50 of Set 8 | shimoda
# Processing Record 1 of Set 9 | conde
# Processing Record 2 of Set 9 | suriapet
# Processing Record 3 of Set 9 | nenjiang
# Processing Record 4 of Set 9 | marivan
# Processing Record 5 of Set 9 | ati
# Processing Record 6 of Set 9 | camapua
# Processing Record 7 of Set 9 | flin flon
# Processing Record 8 of Set 9 | chivacoa
# Processing Record 9 of Set 9 | miedzyrzec podlaski
# Processing Record 10 of Set 9 | paamiut
# Processing Record 11 of Set 9 | kodinsk
# Processing Record 12 of Set 9 | verkhovyna
# Processing Record 13 of Set 9 | la ronge
# Processing Record 14 of Set 9 | razole
# Processing Record 15 of Set 9 | leningradskiy
# Processing Record 16 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 9 | laibin
# Processing Record 18 of Set 9 | boguchany
# Processing Record 19 of Set 9 | dingle
# Processing Record 20 of Set 9 | soloneshnoye
# Processing Record 21 of Set 9 | the valley
# Processing Record 22 of Set 9 | kotel
# Processing Record 23 of Set 9 | bonga
# Processing Record 24 of Set 9 | aasiaat
# Processing Record 25 of Set 9 | aklavik
# Processing Record 26 of Set 9 | northam
# Processing Record 27 of Set 9 | bertoua
# Processing Record 28 of Set 9 | ardmore
# Processing Record 29 of Set 9 | los andes
# Processing Record 30 of Set 9 | flinders
# Processing Record 31 of Set 9 | ancud
# Processing Record 32 of Set 9 | staryy nadym
# Processing Record 33 of Set 9 | eureka
# Processing Record 34 of Set 9 | plouzane
# Processing Record 35 of Set 9 | vostok
# Processing Record 36 of Set 9 | havelock
# Processing Record 37 of Set 9 | novolvovsk
# City not found. Skipping...
# Processing Record 38 of Set 9 | mandera
# Processing Record 39 of Set 9 | tamandare
# Processing Record 40 of Set 9 | moyobamba
# Processing Record 41 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 42 of Set 9 | chenzhou
# Processing Record 43 of Set 9 | key west
# Processing Record 44 of Set 9 | svetlogorsk
# Processing Record 45 of Set 9 | ayan
# Processing Record 46 of Set 9 | icatu
# Processing Record 47 of Set 9 | domoni
# Processing Record 48 of Set 9 | vila franca do campo
# Processing Record 49 of Set 9 | zhangye
# Processing Record 50 of Set 9 | ulaangom
# Processing Record 1 of Set 10 | bilibino
# Processing Record 2 of Set 10 | alihe
# Processing Record 3 of Set 10 | san juancito
# Processing Record 4 of Set 10 | roald
# Processing Record 5 of Set 10 | el dorado
# Processing Record 6 of Set 10 | makakilo city
# Processing Record 7 of Set 10 | bulawayo
# Processing Record 8 of Set 10 | qaqortoq
# Processing Record 9 of Set 10 | solnechnyy
# Processing Record 10 of Set 10 | merauke
# Processing Record 11 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 10 | wolmaranstad
# City not found. Skipping...
# Processing Record 13 of Set 10 | hofn
# Processing Record 14 of Set 10 | otane
# Processing Record 15 of Set 10 | dudinka
# Processing Record 16 of Set 10 | prince rupert
# Processing Record 17 of Set 10 | durango
# Processing Record 18 of Set 10 | souillac
# Processing Record 19 of Set 10 | tecoanapa
# Processing Record 20 of Set 10 | kieta
# Processing Record 21 of Set 10 | quelimane
# Processing Record 22 of Set 10 | baker city
# Processing Record 23 of Set 10 | hay river
# Processing Record 24 of Set 10 | palmas bellas
# Processing Record 25 of Set 10 | marsh harbour
# Processing Record 26 of Set 10 | kuryk
# Processing Record 27 of Set 10 | severo-kurilsk
# Processing Record 28 of Set 10 | tougan
# Processing Record 29 of Set 10 | whittlesea
# Processing Record 30 of Set 10 | joutseno
# Processing Record 31 of Set 10 | bathurst
# Processing Record 32 of Set 10 | axim
# Processing Record 33 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 10 | canico
# Processing Record 35 of Set 10 | aravissos
# Processing Record 36 of Set 10 | harper
# Processing Record 37 of Set 10 | lebu
# Processing Record 38 of Set 10 | port macquarie
# Processing Record 39 of Set 10 | norman wells
# Processing Record 40 of Set 10 | minab
# Processing Record 41 of Set 10 | gumdag
# Processing Record 42 of Set 10 | ziniare
# Processing Record 43 of Set 10 | wattegama
# Processing Record 44 of Set 10 | sayat
# Processing Record 45 of Set 10 | anloga
# Processing Record 46 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 10 | qasigiannguit
# Processing Record 49 of Set 10 | yatou
# Processing Record 50 of Set 10 | bonavista
# Processing Record 1 of Set 11 | xam nua
# Processing Record 2 of Set 11 | teya
# Processing Record 3 of Set 11 | goundam
# Processing Record 4 of Set 11 | tshane
# Processing Record 5 of Set 11 | grand gaube
# Processing Record 6 of Set 11 | pangnirtung
# Processing Record 7 of Set 11 | dongsheng
# Processing Record 8 of Set 11 | klaksvik
# Processing Record 9 of Set 11 | penzance
# Processing Record 10 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 11 | lata
# Processing Record 12 of Set 11 | krasnokamensk
# Processing Record 13 of Set 11 | ostrovnoy
# Processing Record 14 of Set 11 | christchurch
# Processing Record 15 of Set 11 | port-gentil
# Processing Record 16 of Set 11 | puerto maldonado
# Processing Record 17 of Set 11 | okha
# Processing Record 18 of Set 11 | san jose
# Processing Record 19 of Set 11 | ilheus
# Processing Record 20 of Set 11 | praia da vitoria
# Processing Record 21 of Set 11 | blois
# Processing Record 22 of Set 11 | padang
# Processing Record 23 of Set 11 | saint peter
# Processing Record 24 of Set 11 | lhokseumawe
# Processing Record 25 of Set 11 | jinchang
# Processing Record 26 of Set 11 | bahia blanca
# Processing Record 27 of Set 11 | aykhal
# Processing Record 28 of Set 11 | mount gambier
# Processing Record 29 of Set 11 | sakaiminato
# Processing Record 30 of Set 11 | pochutla
# Processing Record 31 of Set 11 | yaan
# Processing Record 32 of Set 11 | guasdualito
# Processing Record 33 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 34 of Set 11 | roebourne
# Processing Record 35 of Set 11 | naze
# Processing Record 36 of Set 11 | nampa
# Processing Record 37 of Set 11 | lewiston
# Processing Record 38 of Set 11 | raga
# Processing Record 39 of Set 11 | tezu
# Processing Record 40 of Set 11 | bijie
# Processing Record 41 of Set 11 | lima
# Processing Record 42 of Set 11 | mendeleyevo
# Processing Record 43 of Set 11 | vardo
# Processing Record 44 of Set 11 | ha
# City not found. Skipping...
# Processing Record 45 of Set 11 | mayor pablo lagerenza
# Processing Record 46 of Set 11 | bereda
# Processing Record 47 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 11 | emmauss
# Processing Record 49 of Set 11 | adrar
# Processing Record 50 of Set 11 | murree
# Processing Record 1 of Set 12 | coronado
# Processing Record 2 of Set 12 | manokwari
# Processing Record 3 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 4 of Set 12 | puerto leguizamo
# Processing Record 5 of Set 12 | jalalabad
# Processing Record 6 of Set 12 | plettenberg bay
# Processing Record 7 of Set 12 | comodoro rivadavia
# Processing Record 8 of Set 12 | airai
# Processing Record 9 of Set 12 | bonthe
# Processing Record 10 of Set 12 | saint-georges
# Processing Record 11 of Set 12 | hamburg
# Processing Record 12 of Set 12 | rio grande
# Processing Record 13 of Set 12 | safaga
# Processing Record 14 of Set 12 | kadur
# Processing Record 15 of Set 12 | sao joao da barra
# Processing Record 16 of Set 12 | celestun
# Processing Record 17 of Set 12 | lucapa
# Processing Record 18 of Set 12 | lalmohan
# Processing Record 19 of Set 12 | tilichiki
# Processing Record 20 of Set 12 | astana
# Processing Record 21 of Set 12 | voyvozh
# Processing Record 22 of Set 12 | vale da amoreira
# Processing Record 23 of Set 12 | nikki
# Processing Record 24 of Set 12 | hvolsvollur
# Processing Record 25 of Set 12 | lamar
# Processing Record 26 of Set 12 | portland
# Processing Record 27 of Set 12 | pasni
# Processing Record 28 of Set 12 | algodones
# Processing Record 29 of Set 12 | kadoma
# Processing Record 30 of Set 12 | tete
# Processing Record 31 of Set 12 | talcahuano
# Processing Record 32 of Set 12 | faya
# Processing Record 33 of Set 12 | uribia
# Processing Record 34 of Set 12 | miquelon
# Processing Record 35 of Set 12 | tucumcari
# Processing Record 36 of Set 12 | yamethin
# Processing Record 37 of Set 12 | husavik
# Processing Record 38 of Set 12 | kirakira
# Processing Record 39 of Set 12 | rodrigues alves
# Processing Record 40 of Set 12 | sarapul
# Processing Record 41 of Set 12 | apache junction
# Processing Record 42 of Set 12 | tokmak
# Processing Record 43 of Set 12 | xining
# Processing Record 44 of Set 12 | seymchan
# Processing Record 45 of Set 12 | santiago de cao
# Processing Record 46 of Set 12 | port moresby
# Processing Record 47 of Set 12 | kralendijk
# Processing Record 48 of Set 12 | serebryansk
# Processing Record 49 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 12 | sept-iles
# Processing Record 1 of Set 13 | dombarovskiy
# Processing Record 2 of Set 13 | tamasopo
# Processing Record 3 of Set 13 | garowe
# Processing Record 4 of Set 13 | senador jose porfirio
# Processing Record 5 of Set 13 | broken hill
# Processing Record 6 of Set 13 | traverse city
# Processing Record 7 of Set 13 | fortuna
# Processing Record 8 of Set 13 | mendi
# Processing Record 9 of Set 13 | villazon
# Processing Record 10 of Set 13 | margate
# Processing Record 11 of Set 13 | khorixas
# Processing Record 12 of Set 13 | zharkovskiy
# Processing Record 13 of Set 13 | dicabisagan
# Processing Record 14 of Set 13 | tupik
# Processing Record 15 of Set 13 | milkovo
# Processing Record 16 of Set 13 | north bend
# Processing Record 17 of Set 13 | port blair
# Processing Record 18 of Set 13 | reftinskiy
# Processing Record 19 of Set 13 | djambala
# Processing Record 20 of Set 13 | lotofaga
# Processing Record 21 of Set 13 | catuday
# Processing Record 22 of Set 13 | kenai
# Processing Record 23 of Set 13 | peking
# Processing Record 24 of Set 13 | katherine
# Processing Record 25 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 26 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 13 | grand baie
# Processing Record 28 of Set 13 | vanimo
# Processing Record 29 of Set 13 | avera
# Processing Record 30 of Set 13 | revelstoke
# Processing Record 31 of Set 13 | hualmay
# Processing Record 32 of Set 13 | korla
# Processing Record 33 of Set 13 | corbelia
# Processing Record 34 of Set 13 | the pas
# Processing Record 35 of Set 13 | alice springs
# Processing Record 36 of Set 13 | vao
# Processing Record 37 of Set 13 | amaigbo
# Processing Record 38 of Set 13 | gambela
# Processing Record 39 of Set 13 | wa
# City not found. Skipping...
# Processing Record 40 of Set 13 | baykit
# Processing Record 41 of Set 13 | qurayyat
# Processing Record 42 of Set 13 | shangrao
# Processing Record 43 of Set 13 | soufriere
# Processing Record 44 of Set 13 | iguape
# Processing Record 45 of Set 13 | sairang
# Processing Record 46 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 13 | si chiang mai
# Processing Record 48 of Set 13 | yamada
# Processing Record 49 of Set 13 | zhezkazgan
# Processing Record 50 of Set 13 | kaili
# Processing Record 1 of Set 14 | kalabo
# Processing Record 2 of Set 14 | burnie
# Processing Record 3 of Set 14 | guerrero negro
# Processing Record 4 of Set 14 | preobrazheniye
# Processing Record 5 of Set 14 | half moon bay
# Processing Record 6 of Set 14 | kormend
# Processing Record 7 of Set 14 | owando
# Processing Record 8 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 14 | fuerte olimpo
# Processing Record 10 of Set 14 | ola
# Processing Record 11 of Set 14 | petrovsk-zabaykalskiy
# Processing Record 12 of Set 14 | sao miguel do araguaia
# Processing Record 13 of Set 14 | alofi
# Processing Record 14 of Set 14 | acapulco
# Processing Record 15 of Set 14 | waingapu
# Processing Record 16 of Set 14 | arman
# Processing Record 17 of Set 14 | qinhuangdao
# Processing Record 18 of Set 14 | tumbagaan
# Processing Record 19 of Set 14 | sertolovo
# Processing Record 20 of Set 14 | evensk
# Processing Record 21 of Set 14 | springbok
# Processing Record 22 of Set 14 | kalmunai
# Processing Record 23 of Set 14 | gasa
# Processing Record 24 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 14 | chokwe
# Processing Record 26 of Set 14 | isla vista
# Processing Record 27 of Set 14 | winneba
# Processing Record 28 of Set 14 | port augusta
# Processing Record 29 of Set 14 | caruaru
# Processing Record 30 of Set 14 | ewa beach
# Processing Record 31 of Set 14 | praia
# Processing Record 32 of Set 14 | ayagoz
# Processing Record 33 of Set 14 | ayame
# Processing Record 34 of Set 14 | luan
# Processing Record 35 of Set 14 | chipinge
# Processing Record 36 of Set 14 | itarema
# Processing Record 37 of Set 14 | leshukonskoye
# Processing Record 38 of Set 14 | putina
# Processing Record 39 of Set 14 | lusambo
# Processing Record 40 of Set 14 | bonanza
# Processing Record 41 of Set 14 | san antonio
# Processing Record 42 of Set 14 | tankhoy
# Processing Record 43 of Set 14 | viedma
# Processing Record 44 of Set 14 | rabo de peixe
# Processing Record 45 of Set 14 | aracatuba
# Processing Record 46 of Set 14 | moba
# Processing Record 47 of Set 14 | ellensburg
# Processing Record 48 of Set 14 | george
# Processing Record 49 of Set 14 | aginskoye
# Processing Record 50 of Set 14 | karratha
# Processing Record 1 of Set 15 | havoysund
# Processing Record 2 of Set 15 | alugan
# Processing Record 3 of Set 15 | porbandar
# Processing Record 4 of Set 15 | hinton
# Processing Record 5 of Set 15 | morro bay
# Processing Record 6 of Set 15 | kokopo
# Processing Record 7 of Set 15 | falun
# Processing Record 8 of Set 15 | mizdah
# Processing Record 9 of Set 15 | tocopilla
# Processing Record 10 of Set 15 | ritchie
# Processing Record 11 of Set 15 | maragogi
# Processing Record 12 of Set 15 | general roca
# Processing Record 13 of Set 15 | tuapse
# Processing Record 14 of Set 15 | hamilton
# Processing Record 15 of Set 15 | williston
# Processing Record 16 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 18 of Set 15 | sorong
# Processing Record 19 of Set 15 | cherepovets
# Processing Record 20 of Set 15 | ixtapa
# Processing Record 21 of Set 15 | svetlyy
# Processing Record 22 of Set 15 | powell river
# Processing Record 23 of Set 15 | bording
# Processing Record 24 of Set 15 | potchefstroom
# Processing Record 25 of Set 15 | warmbad
# Processing Record 26 of Set 15 | veraval
# Processing Record 27 of Set 15 | bandrele
# Processing Record 28 of Set 15 | parras
# City not found. Skipping...
# Processing Record 29 of Set 15 | marzuq
# Processing Record 30 of Set 15 | tambura
# Processing Record 31 of Set 15 | ishigaki
# Processing Record 32 of Set 15 | fare
# Processing Record 33 of Set 15 | awbari
# Processing Record 34 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 15 | ponta delgada
# Processing Record 36 of Set 15 | khandbari
# Processing Record 37 of Set 15 | tutoia
# Processing Record 38 of Set 15 | ladybrand
# Processing Record 39 of Set 15 | goure
# Processing Record 40 of Set 15 | les cayes
# Processing Record 41 of Set 15 | ikalamavony
# Processing Record 42 of Set 15 | moindou
# Processing Record 43 of Set 15 | krasnovishersk
# Processing Record 44 of Set 15 | sosnovo-ozerskoye
# Processing Record 45 of Set 15 | adzope
# Processing Record 46 of Set 15 | piaseczno
# Processing Record 47 of Set 15 | ouadda
# Processing Record 48 of Set 15 | ndele
# Processing Record 49 of Set 15 | davila
# Processing Record 50 of Set 15 | porto novo
# Processing Record 1 of Set 16 | oranjestad
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0       Anshun  26.2500  105.9333     40.14     overcast clouds        74
# 1     Sidi Ali  36.0998    0.4206     61.57       broken clouds        81
# 2   Nikolskoye  59.7035   30.7861     19.29     overcast clouds        87
# 3        Ukiah  39.1502 -123.2078     48.36     overcast clouds        83
# 4  Port Alfred -33.5906   26.8910     71.19     overcast clouds        90
# 5       Barrow  71.2906 -156.7887      6.82           clear sky        78
# 6     Filingue  14.3521    3.3168     74.08     overcast clouds        12
# 7        Salta -24.7859  -65.4117     90.19    scattered clouds        33
# 8  Fort Nelson  58.8053 -122.7002      2.95          few clouds        66
# 9      Mataura -46.1927  168.8643     63.48     overcast clouds        60
#
#    Cloudiness  Wind Speed Country                 Date
# 0         100        6.85      CN  2022-12-11 21:43:49
# 1          67       25.50      DZ  2022-12-11 21:43:49
# 2         100       11.52      RU  2022-12-11 21:43:49
# 3         100        5.75      US  2022-12-11 21:43:50
# 4          98        8.01      ZA  2022-12-11 21:43:50
# 5           0       25.32      US  2022-12-11 21:43:51
# 6          96       10.13      NE  2022-12-11 21:43:51
# 7          40        6.91      AR  2022-12-11 21:43:51
# 8          20        3.00      CA  2022-12-11 21:43:52
# 9          85        1.74      NZ  2022-12-11 21:43:52

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Anshun      CN  26.2500  105.9333     40.14        74         100
# 1     Sidi Ali      DZ  36.0998    0.4206     61.57        81          67
# 2   Nikolskoye      RU  59.7035   30.7861     19.29        87         100
# 3        Ukiah      US  39.1502 -123.2078     48.36        83         100
# 4  Port Alfred      ZA -33.5906   26.8910     71.19        90          98
#
#    Wind Speed Current Description
# 0        6.85     overcast clouds
# 1       25.50       broken clouds
# 2       11.52     overcast clouds
# 3        5.75     overcast clouds
# 4        8.01     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
